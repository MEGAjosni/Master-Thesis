# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
name = 'plasma_sa'
data = np.load(name + '.npy')

# %%
# loss = data[::6, 0]
# pde_loss = data[::6, 1]
# boundary_flux_loss = data[::6, 2]

# %%
plt.figure( figsize=(10, 3) )
plt.plot(loss, label='Total loss', color='blue')
plt.plot(pde_loss, label='PDE loss', color='green')
plt.plot(boundary_flux_loss, label='Boundary Flux loss', color='red')
plt.yscale('log')
plt.xlabel('Epoch')
plt.xlim(0, len(loss))
plt.legend()
plt.savefig(name + '.pdf', bbox_inches='tight', format='pdf')
plt.show()
